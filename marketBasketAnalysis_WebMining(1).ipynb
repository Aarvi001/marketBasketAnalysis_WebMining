# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
import plotly.express as px

# %%
df = pd.read_csv(r'https://github.com/Aarvi001/marketBasketAnalysis_WebMining/raw/master/Assignment-1_Data.csv',sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning:
#
# Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %% [markdown]
# ## Given Data

# %%
# Shape of the data
df.shape
# Out:
# (522064, 7)

# %%
# data Types
df.dtypes
# Out:
# BillNo         object
# Itemname       object
# Quantity        int64
# Date           object
# Price          object
# CustomerID    float64
# Country        object
# dtype: object

# %%
# head of dataframe
df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
# Checking for null values
df.isnull().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %% [markdown]
# ### Dropping NA Values

# %%
df.dropna(inplace=True)

# %%
# Quantity and Price should be  greater than 0
df = df[df["Quantity"] > 0]

# %%
# Changing the price column datatype as a numeric
df ['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df = df[df["Price"] > 0]

# %%
df.isnull().sum()
# Out:
# BillNo        0
# Itemname      0
# Quantity      0
# Date          0
# Price         0
# CustomerID    0
# Country       0
# dtype: int64

# %%
df.shape
# Out:
# (1537, 7)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Calculating Total Price

# %%
total_sales = df
total_sales["Total_Price"] = total_sales["Price"] * total_sales["Quantity"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Total sales per customer

# %%
total_sales_per_customer = total_sales.groupby(["CustomerID", "Country"]).agg({"Total_Price": "sum"})
total_sales_per_customer.head(10)
# Out:
#                         Total_Price
# CustomerID Country
# 12349.0    Italy              300.0
# 12350.0    Norway              40.0
# 12352.0    Norway             280.0
# 12356.0    Portugal           324.0
# 12357.0    Switzerland         25.0
# 12358.0    Austria            240.0
# 12360.0    Austria            360.0
# 12361.0    Belgium             15.0
# 12362.0    Belgium            489.0
# 12364.0    Belgium            105.0

# %%
# Top 10 shoppers
total_sales_per_customer.reset_index(inplace=True)
total_sales_per_customer.sort_values(by = "Total_Price", ascending = False).head(10)
# Out:
#      CustomerID         Country  Total_Price
# 577     17450.0  United Kingdom      10496.0
# 471     15581.0  United Kingdom       2750.0
# 67      12471.0         Germany       2400.0
# 412     14607.0  United Kingdom       2120.0
# 112     12540.0           Spain       1820.0
# 246     12748.0  United Kingdom       1788.0
# 460     15482.0  United Kingdom       1646.0
# 414     14646.0     Netherlands       1458.0
# 201     12681.0          France       1422.0
# 198     12678.0          France       1297.0

# %% [markdown]
# VISUALIZATION

# %%
# consider that for all time period
data_fig = total_sales_per_customer.sort_values(by = "Total_Price", ascending = False).head(100)

fig = px.scatter(data_fig, x="CustomerID", y="Total_Price",
	         size="Total_Price", color="Country",
                 hover_name="Country", log_x=True, size_max=60, title="Top 100 Shoppers and Their Contries & Shopping Amounts")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="31e3aea9-4095-43f4-91fc-9e7f3c3649b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31e3aea9-4095-43f4-91fc-9e7f3c3649b3")) {                    Plotly.newPlot(                        "31e3aea9-4095-43f4-91fc-9e7f3c3649b3",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=United Kingdom<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom"],"legendgroup":"United Kingdom","marker":{"color":"#636efa","size":[10496.0,2750.0,2120.0,1788.0,1646.0,1105.0,870.0,750.0,655.0,600.0,590.0,545.0,545.0,525.0,500.0,500.0,500.0,500.0,500.0,480.0,455.0,455.0,440.0,440.0,440.0,392.0,390.0,375.0,350.0,330.0,330.0,295.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"United Kingdom","orientation":"v","showlegend":true,"x":[17450.0,15581.0,14607.0,12748.0,15482.0,17500.0,13983.0,14973.0,14711.0,15299.0,13452.0,17406.0,16607.0,16949.0,17690.0,16003.0,15727.0,16316.0,15159.0,17949.0,12909.0,14030.0,13631.0,18233.0,15524.0,14195.0,17581.0,15874.0,16873.0,14088.0,13523.0,13145.0],"xaxis":"x","y":[10496.0,2750.0,2120.0,1788.0,1646.0,1105.0,870.0,750.0,655.0,600.0,590.0,545.0,545.0,525.0,500.0,500.0,500.0,500.0,500.0,480.0,455.0,455.0,440.0,440.0,440.0,392.0,390.0,375.0,350.0,330.0,330.0,295.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Germany<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany","Germany"],"legendgroup":"Germany","marker":{"color":"#EF553B","size":[2400.0,1278.0,972.0,918.0,666.0,666.0,630.0,630.0,576.0,576.0,540.0,523.0,504.0,493.0,486.0,396.0,396.0,360.0,306.0,306.0,306.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"Germany","orientation":"v","showlegend":true,"x":[12471.0,12621.0,12569.0,12476.0,12626.0,12720.0,12668.0,12474.0,12647.0,12481.0,12524.0,12590.0,12472.0,12712.0,12705.0,12627.0,12480.0,13815.0,12619.0,12662.0,12709.0],"xaxis":"x","y":[2400.0,1278.0,972.0,918.0,666.0,666.0,630.0,630.0,576.0,576.0,540.0,523.0,504.0,493.0,486.0,396.0,396.0,360.0,306.0,306.0,306.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Spain<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Spain","Spain","Spain","Spain"],"legendgroup":"Spain","marker":{"color":"#00cc96","size":[1820.0,728.0,616.0,588.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name":"Spain","orientation":"v","showlegend":true,"x":[12540.0,12502.0,12597.0,12484.0],"xaxis":"x","y":[1820.0,728.0,616.0,588.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country=Netherlands<br>CustomerID=%{x}<br>Total_Price=%{marker.size}<extra></extra>","hovertext":["Netherlands"],"legendgroup":"Netherlands","marker":{"color":"#ab63fa","size":[1458.0],"sizemode":"area","sizeref":2.9155555555555557,"symbol":"circle"},"mode":"markers","name" ...

# %%
# consider that for all time period
#total_sales_per_customer.head(20)
total_sales_per_customer.groupby(["Country"]).agg({"Total_Price":"sum"}).reset_index().sort_values(by="Total_Price", ascending=False )
# Out:
#            Country  Total_Price
# 17  United Kingdom      53159.0
# 4          Germany      21155.0
# 3           France      15713.0
# 14           Spain       5917.0
# 2          Belgium       4269.0
# 16     Switzerland       4027.0
# 10          Norway       2996.0
# 12        Portugal       2508.0
# 9      Netherlands       1947.0
# 7            Italy       1663.0
# 15          Sweden       1539.0
# 1          Austria       1456.0
# 8            Malta        655.0
# 11          Poland        360.0
# 0        Australia        350.0
# 5           Greece        335.0
# 13       Singapore        315.0
# 6           Israel        255.0

# %%
# consider that for all time period
data = total_sales_per_customer.groupby(["Country"]).agg({"Total_Price":"sum"}).reset_index().sort_values(by="Total_Price", ascending=False )
fig = px.bar(data, x='Country', y='Total_Price' , title = "Shopping Amounts by Countries")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="335e3dec-8e5f-494e-972a-5732bd808d6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("335e3dec-8e5f-494e-972a-5732bd808d6c")) {                    Plotly.newPlot(                        "335e3dec-8e5f-494e-972a-5732bd808d6c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Total_Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United Kingdom","Germany","France","Spain","Belgium","Switzerland","Norway","Portugal","Netherlands","Italy","Sweden","Austria","Malta","Poland","Australia","Greece","Singapore","Israel"],"xaxis":"x","y":[53159.0,21155.0,15713.0,5917.0,4269.0,4027.0,2996.0,2508.0,1947.0,1663.0,1539.0,1456.0,655.0,360.0,350.0,335.0,315.0,255.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %%
#df_united_kingdom = df.loc[df["Country"]=="United Kingdom"]
df_invoice_product_matrix = df.groupby(['BillNo', 'Itemname']).  \
    agg({"Quantity": "sum"}).unstack().fillna(0).  \
    applymap(lambda x: 1 if x > 0 else 0)

df_invoice_product_matrix.head(10)
# Out:
#                                  Quantity                             \
# Itemname BEADED CHANDELIER T-LIGHT HOLDER BILI NUT AND WOOD NECKLACE
# BillNo
# 536370                                  0                          0
# 536392                                  0                          0
# 536403                                  0                          0
# 536527                                  0                          0
# 536779                                  0                          0
# 536835                                  0                          0
# 536840                                  0                          0
# 536852                                  0                          0
# 536858                                  0                          0
# 536861                                  0                          0
#
#                                                             \
# Itemname BLING KEY RING STAND BOTANICAL GARDENS WALL CLOCK
# BillNo
# 536370                      0                            0
# 536392                      0                            0
# 536403                      0                            0
# 536527                      0                            0
# 536779                      0                            0
# 536835                      0                            0
# 536840                      0                            0
# 536852                      0                            0
# 536858                      0                            0
# 536861                      0                            0
#
#                                                                \
# Itemname BREAD BIN DINER STYLE PINK BREAD BIN DINER STYLE RED
# BillNo
# 536370                            0                         0
# 536392                            0                         0
# 536403                            0                         0
# 536527                            0                         0
# 536779                            0                         0
# 536835                            0                         0
# 536840                            0                         0
# 536852                            0                         0
# 536858                            0                         0
# 536861                            0                         0
#
#                                                                      \
# Itemname BROWN CHECK CAT DOORSTOP BROWN KUKUI COCONUT SEED NECKLACE
# BillNo
# 536370                          0                                 0
# 536392                          0                                 0
# 536403                          0                                 0
# 536527                          0                                 0
# 536779                          0                                 0
# 536835                          0                                 0
# 536840                          0                                 0
# 536852                          0                                 0
# 536858                          0                                 0
# 536861                          0                                 0
#
#                                                          ...  \
# Itemname Bank Charges CAKE STAND VICTORIAN FILIGREE MED  ...
# BillNo                                                   ...
# 536370              0                                 0  ...
# 536392              0                                 0  ...
# 536403              0                                 0  ...
# 536527              0                                 0  ...
# 536779              1                                 0  ...
# 536835              0                                 0  ...
# 536840              0                                 0  ...
# 536852              0                                 0  ...
# 536858              0                                 0  ...
# 536861              0                                 0  ...
#
#                                                                                \
# Itemname SMALL WHITE RETROSPOT MUG IN BOX SPOTTED WHITE NATURAL SEED NECKLACE
# BillNo
# 536370                                  0                                   0
# 536392                                  0                                   0
# 536403                                  0                                   0
# 536527                                  0                                   0
# 536779                                  0                                   0
# 536835                                  0                                   0
# 536840                                  0                                   0
# 536852                                  0                                   0
# 536858                                  0                                   0
# 536861                                  0                                   0
#
#                                                            \
# Itemname TWO DOOR CURIO CABINET UTILTY CABINET WITH HOOKS
# BillNo
# 536370                        0                         0
# 536392                        0                         0
# 536403                        0                         0
# 536527                        0                         0
# 536779                        0                         0
# 536835                        0                         0
# 536840                        0                         0
# 536852                        0                         0
# 536858                        0                         0
# 536861                        0                         0
#
#                                                                        \
# Itemname VANILLA SCENT CANDLE JEWELLED BOX VICTORIAN SEWING BOX SMALL
# BillNo
# 536370                                   0                          0
# 536392                                   0                          0
# 536403                                   0                          0
# 536527                                   0                          0
# 536779                                   0                          0
# 536835                                   0                          0
# 536840                                   0                          0
# 536852                                   0                          0
# 536858                                   0                          0
# 536861                                   0                          0
#
#                                                                    \
# Itemname VINTAGE BLUE KITCHEN CABINET VINTAGE RED KITCHEN CABINET
# BillNo
# 536370                              0                           0
# 536392                              0                           0
# 536403                              0                           0
# 536527                              0                           0
# 536779                              0                           0
# 536835                              0                           1
# 536840                              0                           0
# 536852                              0                           0
# 536858                              0                           0
# 536861                              0                           0
#
#
# Itemname VINTAGE WOODEN BAR STOOL WOODEN ADVENT CALENDAR CREAM
# BillNo
# 536370                          0                            0
# 536392                          0                            0
# 536403                          0                            0
# 536527                          0                            0
# 536779                          0                            0
# 536835                          0                            0
# 536840                          0                            0
# 536852                          0                            0
# 536858                          0                            0
# 536861                          0                            0
#
# [10 rows x 73 columns]

# %% [markdown]
# ASSOCIATIVE RULE MINING

# %%
frequent_itemsets = apriori(df_invoice_product_matrix, min_support=0.001, use_colnames=True) 
frequent_itemsets.sort_values("support", ascending=False)
# Out:
#        support                                           itemsets
# 30    0.715076                              ((Quantity, POSTAGE))
# 27    0.054633                    ((Quantity, Next Day Carriage))
# 3     0.043568         ((Quantity, BOTANICAL GARDENS WALL CLOCK))
# 26    0.031120                               ((Quantity, Manual))
# 23    0.027663        ((Quantity, LOVE SEAT ANTIQUE WHITE METAL))
# ...        ...                                                ...
# 573   0.001383  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...
# 574   0.001383  ((Quantity, DOORMAT RED RETROSPOT), (Quantity,...
# 575   0.001383  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...
# 576   0.001383  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 1084  0.001383  ((Quantity, DOORMAT RED RETROSPOT), (Quantity,...
#
# [1085 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="support", min_threshold=0.001)
rules.sort_values("support", ascending=False).head(10)
# Out:
#                                            antecedents  \
# 123         ((Quantity, VINTAGE BLUE KITCHEN CABINET))
# 122          ((Quantity, VINTAGE RED KITCHEN CABINET))
# 17   ((Quantity, SPOTTED WHITE NATURAL SEED NECKLACE))
# 14     ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))
# 137  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...
# 138  ((Quantity, BILI NUT AND WOOD NECKLACE), (Quan...
# 139    ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))
# 140           ((Quantity, BILI NUT AND WOOD NECKLACE))
# 141      ((Quantity, RED KUKUI COCONUT SEED NECKLACE))
# 119      ((Quantity, RED KUKUI COCONUT SEED NECKLACE))
#
#                                            consequents  antecedent support  \
# 123          ((Quantity, VINTAGE RED KITCHEN CABINET))            0.012448
# 122         ((Quantity, VINTAGE BLUE KITCHEN CABINET))            0.024896
# 17     ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))            0.003458
# 14       ((Quantity, RED KUKUI COCONUT SEED NECKLACE))            0.004149
# 137           ((Quantity, BILI NUT AND WOOD NECKLACE))            0.002766
# 138    ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE))            0.002766
# 139  ((Quantity, BILI NUT AND WOOD NECKLACE), (Quan...            0.004149
# 140  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...            0.002766
# 141  ((Quantity, BROWN KUKUI COCONUT SEED NECKLACE)...            0.007607
# 119  ((Quantity, SPOTTED WHITE NATURAL SEED NECKLACE))            0.007607
#
#      consequent support   support  confidence        lift  leverage  \
# 123            0.024896  0.006916    0.555556   22.314815  0.006606
# 122            0.012448  0.006916    0.277778   22.314815  0.006606
# 17             0.004149  0.002766    0.800000  192.800000  0.002752
# 14             0.007607  0.002766    0.666667   87.636364  0.002735
# 137            0.002766  0.002766    1.000000  361.500000  0.002759
# 138            0.004149  0.002766    1.000000  241.000000  0.002755
# 139            0.002766  0.002766    0.666667  241.000000  0.002755
# 140            0.002766  0.002766    1.000000  361.500000  0.002759
# 141            0.002766  0.002766    0.363636  131.454545  0.002745
# 119            0.003458  0.002766    0.363636  105.163636  0.002740
#
#      conviction
# 123    2.193983
# 122    1.367380
# 17     4.979253
# 14     2.977178
# 137         inf
# 138         inf
# 139    2.991701
# 140         inf
# 141    1.567082
# 119    1.565995

# %%
sorted_rules = rules.sort_values("lift", ascending=False)
rules.sort_values("lift", ascending=False).head(10)
# Out:
#                                              antecedents  \
# 113      ((Quantity, MARIE ANTOINETTE TRINKET BOX GOLD))
# 114      ((Quantity, VANILLA SCENT CANDLE JEWELLED BOX))
# 112    ((Quantity, MARIE ANTOINETTE TRINKET BOX SILVER))
# 115     ((Quantity, OCEAN SCENT CANDLE IN JEWELLED BOX))
# 38147  ((Quantity, DOORMAT NEW ENGLAND), (Quantity, D...
# 38078  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...
# 38067  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38068  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38069  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...
# 38070  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...
#
#                                              consequents  antecedent support  \
# 113    ((Quantity, MARIE ANTOINETTE TRINKET BOX SILVER))            0.001383
# 114     ((Quantity, OCEAN SCENT CANDLE IN JEWELLED BOX))            0.001383
# 112      ((Quantity, MARIE ANTOINETTE TRINKET BOX GOLD))            0.001383
# 115      ((Quantity, VANILLA SCENT CANDLE JEWELLED BOX))            0.001383
# 38147  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.002075
# 38078  ((Quantity, DOORMAT MERRY CHRISTMAS RED), (Qua...            0.002075
# 38067  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.001383
# 38068  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.002075
# 38069  ((Quantity, DOORMAT HEARTS), (Quantity, DOORMA...            0.001383
# 38070  ((Quantity, DOORMAT SPOTTY HOME SWEET HOME), (...            0.001383
#
#        consequent support   support  confidence   lift  leverage  conviction
# 113              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 114              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 112              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 115              0.001383  0.001383    1.000000  723.0  0.001381         inf
# 38147            0.001383  0.001383    0.666667  482.0  0.001380    2.995851
# 38078            0.001383  0.001383    0.666667  482.0  0.001380    2.995851
# 38067            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38068            0.001383  0.001383    0.666667  482.0  0.001380    2.995851
# 38069            0.002075  0.001383    1.000000  482.0  0.001380         inf
# 38070            0.002075  0.001383    1.000000  482.0  0.001380         inf

# %%
# We can try below products in the loop
# ('Quantity', 'VANILLA SCENT CANDLE JEWELLED BOX')
# ('Quantity', 'DOORMAT MERRY CHRISTMAS RED')
# ('Quantity', 'DOORMAT RESPECTABLE HOUSE')
# ('Quantity', 'DOORMAT SPOTTY HOME SWEET HOME')
# ('Quantity', 'DOORMAT UNION FLAG')
# ('Quantity', 'DOORMAT UNION FLAG')

recommendation_list = []

for i, product in sorted_rules["antecedents"].items():
    for j in list(product):
        if j == ('Quantity', 'MARIE ANTOINETTE TRINKET BOX GOLD'):
            recommendation_list.append(list(sorted_rules.iloc[i]["consequents"]))

# %%
print(recommendation_list)
# Out:
# [[('Quantity', 'DOORMAT HEARTS'), ('Quantity', 'DOORMAT FAIRY CAKE'), ('Quantity', 'DOORMAT NEW ENGLAND')]]
